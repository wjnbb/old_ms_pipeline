# %%
#This workflow includes all four main sample types
# Bio, Media/Control, Blanks, QCs
# Blank Subtraction implemented
# Multi Bio Multi control FCs
# correct sample naming and assignment of bio_media_linkers required for correct FC calcs

from src.assign_global_variables import path, peaklist, Blank_identifier, QC_identifier
from src.Avg_SD_RSD_calcs import avg_sd_rsd
from src.Blank_Filtering import blank_filter
from src.detect_sample_groups import detect_sample_groups
from src.Export_Peak_Table import export_PT
from src.FC_calculator import FC_MultiBio_vs_MultiControl
from src.Filter_Row_Indices import single_table_filt, module_tables_filt
from src.Fraction_filter import fraction_filter
from src.get_group_heights import get_single_group_heights
from src.ID_levels import ID_levels
from src.MZMine3_columns import mzmine3_cols
from src.MZMine3_module_divider import divide_mzmine3_table
from src.Plot_RSDs import plot_rsd_vs_rt
from src.read_peak_table import read_mzmine3_peaktable
from src.sample_names import get_sample_names

#Read in and organise the peak table and detect sample groups
mzmine3 = read_mzmine3_peaktable(path, peaklist)
cols = mzmine3_cols(mzmine3)
mods = divide_mzmine3_table(mzmine3, cols)
names = get_sample_names(mods[6])
groups = detect_sample_groups(names)
heights = get_single_group_heights(mods[6], names)

#Calculate summary stats for all features in all groups
bio_stats = avg_sd_rsd(heights[0], groups[4], groups[0])
media_stats = avg_sd_rsd(heights[1], groups[5], groups[1])
blank_stats = avg_sd_rsd(heights[2], Blank_identifier, groups[2])
qc_stats = avg_sd_rsd(heights[3], QC_identifier, groups[3])

#Blank Filtering
blank_i_filt = blank_filter(bio_stats, media_stats, qc_stats, blank_stats)
bio_stats = single_table_filt(blank_i_filt[0], bio_stats)
media_stats = single_table_filt(blank_i_filt[0], media_stats)
qc_stats = single_table_filt(blank_i_filt[0], qc_stats)
mods_blank_filt = module_tables_filt(blank_i_filt[0], mods)

#plot feature reproducibility across the run
plot_rsd_vs_rt(bio_stats, media_stats, qc_stats, mods_blank_filt[7], show_plot=False)

#Calculate FCs
FC_table = FC_MultiBio_vs_MultiControl(groups[4], bio_stats, media_stats)

#Add levels of ID
ID_levels(mods_blank_filt)

#Export peak table for the whole dataset
export_PT(mods_blank_filt, FC_table, bio_stats, media_stats, qc_stats, blank_stats, heights)

#Export stringently filtered peak tables for individual biological samples
fraction_filter(bio_stats, groups[4], FC_table, mods_blank_filt)
# Out:
# current working directory is...
# C:/Users/WilliamNash/Bactobio Dropbox/Baccuico/LAB Work/Lab Work - Will/Mass_spec_data/20231108_G-BH30/MZMine3/
#
# completed MZMine3 peak table dividing
#
# Biological sample identifier used is....BH30
# Media or control sample identifier used is....M_
# Blank sample identifier used is....Blank
# QC sample identifier used is....QC
#
#
# First ten biological samples names are...
# ['G-BH30_3039_1_P1Fr3_rep1.mzML', 'G-BH30_3039_1_P1Fr3_rep2.mzML', 'G-BH30_3039_1_P1Fr3_rep3.mzML', 'G-BH30_3039_1_P1Fr4_rep1.mzML', 'G-BH30_3039_1_P1Fr4_rep2.mzML', 'G-BH30_3039_1_P1Fr4_rep3.mzML', 'G-BH30_3039_1_P1Fr7_rep1.mzML', 'G-BH30_3039_1_P1Fr7_rep2.mzML', 'G-BH30_3039_1_P1Fr7_rep3.mzML']
# Number of Biological samples found = 15
# ['G-BH30_3039_1_P1Fr3_', 'G-BH30_3039_1_P1Fr4_', 'G-BH30_3039_1_P1Fr7_', 'G-BH30_3039_1_P1Fr8_', 'G-BH30_3039_Load_1_']
# Number of Biological groups found = 5
#
# First ten media/control samples names are...
# ['M_3039_Load_rep1.mzML', 'M_3039_Load_rep2.mzML', 'M_3039_Load_rep3.mzML', 'M_3039_P1Fr3_rep1.mzML', 'M_3039_P1Fr3_rep2.mzML', 'M_3039_P1Fr3_rep3.mzML', 'M_3039_P1Fr4_rep1.mzML', 'M_3039_P1Fr4_rep2.mzML', 'M_3039_P1Fr4_rep3.mzML']
# Number of Media/control samples found = 15
# ['M_3039_Load_', 'M_3039_P1Fr3_', 'M_3039_P1Fr4_', 'M_3039_P1Fr7_', 'M_3039_P1Fr8_']
# Number of Media groups found = 5
#
# First ten blank samples names are...
# ['Blank_rep1.mzML', 'Blank_rep10.mzML', 'Blank_rep11.mzML', 'Blank_rep12.mzML', 'Blank_rep2.mzML', 'Blank_rep3.mzML', 'Blank_rep4.mzML', 'Blank_rep5.mzML', 'Blank_rep6.mzML']
# Number of blank samples found = 12
#
# No QC samples present
#
# Blank threshold applied for filtering is 5
# 5985 features left after blank filtering
# 98.34045349983569 % of features left after blank filtering
#
# 204 level 2 annotations assigned
# 3269 level 3 annotations assigned
# 0 level 4 annotations assigned
# 2512 level 5 annotations assigned
#
# FC threshold applied is 10
# RSD threshold applied is 30
# Peak height threshold applied is 10000
#
# 731 features meet the filtering criteria in G-BH30_3039_1_P1Fr3_
# 632 features meet the filtering criteria in G-BH30_3039_1_P1Fr4_
# 1041 features meet the filtering criteria in G-BH30_3039_1_P1Fr7_
# 1331 features meet the filtering criteria in G-BH30_3039_1_P1Fr8_
# 413 features meet the filtering criteria in G-BH30_3039_Load_1_
